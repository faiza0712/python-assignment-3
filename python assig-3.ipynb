# %%
#TASK 1
import random

secret_number = random.randint(1, 10)
attempts = 3

while attempts > 0:
    guess = int(input("Guess the number (between 1 and 10): "))

    if guess < 1 or guess > 10:
        print("Your guess is out of range. Please guess a number between 1 and 10.")
        continue

    attempts = attempts - 1

    if guess > secret_number:
        print("Too high. Try again.")
    elif guess < secret_number:
        print("Too low. Try again.")
    else:
        print("Congratulations! You guessed the correct number.")
        break

else:
    print("Better luck next time!")
# Out:
# Guess the number (between 1 and 10): 3
# Too low. Try again.
# Guess the number (between 1 and 10): 7
# Congratulations! You guessed the correct number.

# %%
#TASK 2
number = int(input("Enter the number for which you want the multiplication table: "))

for i in range(1, 11):
    result = number * i
    print(number, "x", i, "=", result)
# Out:
# Enter the number for which you want the multiplication table: 6
# 6 x 1 = 6
# 6 x 2 = 12
# 6 x 3 = 18
# 6 x 4 = 24
# 6 x 5 = 30
# 6 x 6 = 36
# 6 x 7 = 42
# 6 x 8 = 48
# 6 x 9 = 54
# 6 x 10 = 60

# %%
#TASK 3
def calculate_bmi(weight, height):
    bmi = weight / (height ** 2)
    return bmi

weight = float(input("Enter your weight in kg: "))
height = float(input("Enter your height in meters: "))

bmi = calculate_bmi(weight, height)

print("Your BMI is:", round(bmi, 2))
# Out:
# Enter your weight in kg: 63
# Enter your height in meters: 1.65
# Your BMI is: 23.14

# %% [markdown]
# # PYTHON ASSIGNMENT 3
#
# ## Loops, Control Statements & Functions
#
# ### TASK 1: NUMBER GUESSING GAME
#
# **Objective:**
# To create a number guessing game using a `while` loop and control statements.
#
# **Concepts Used:**
# While loop, if-else, `break`, `continue`, random module, and `randint()`.
#
# **Description:**
# The program generates a random number between 1 and 10. The user gets 3 attempts to guess the number. The program provides feedback if the guess is too high, too low, or out of range. `continue` is used for invalid guesses, `break` is used when the correct number is guessed, and `else` displays a message when all attempts are completed.
#
# **Result:**
# The number guessing game was successfully implemented.
#
# ---
#
# ### TASK 2: MULTIPLICATION TABLE GENERATOR
#
# **Objective:**
# To generate a multiplication table from 1 to 10 using a `for` loop.
#
# **Concepts Used:**
# For loop, `range()`, user input, and arithmetic operators.
#
# **Description:**
# The program asks the user to enter a number and generates its multiplication table from 1 to 10 using a `for` loop and the `range()` function.
#
# **Result:**
# The multiplication table was successfully generated.
#
# ---
#
# ### TASK 3: BMI CALCULATOR
#
# **Objective:**
# To calculate the Body Mass Index (BMI) using a user-defined function.
#
# **Formula:**
# BMI = Weight (kg) / Height (m)²
#
# **Concepts Used:**
# Functions, parameters, return statement, user input, and arithmetic operators.
#
# **Description:**
# The program accepts the user's weight and height and uses the `calculate_bmi()` function to calculate and display the BMI.
#
# **Result:**
# The BMI was successfully calculated using a Python function.
#
# ---
#
# ### CONCLUSION
#
# This assignment helped in understanding **loops, control statements, functions, user input, and basic Python programming concepts**.
